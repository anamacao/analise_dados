# %% [markdown]
# <a href="https://colab.research.google.com/github/anamacao/analise_dados/blob/main/dados/Analise_dados_06_combinando_dataframe_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Combinando dataframe

# %%
import numpy as np
import pandas as pd

# %%
argentina = "https://raw.githubusercontent.com/anamacao/analise_dados/main/dados/MERCOSUL_Argentina_API_ARG_DS2_en_csv_v2_5255054.csv"
brasil = "https://raw.githubusercontent.com/anamacao/analise_dados/main/dados/MERCOSUL_Brasil_API_BRA_DS2_pt_csv_v2_4911136.csv"
uruguai = "https://raw.githubusercontent.com/anamacao/analise_dados/main/dados/MERCOSUL_Uruguai_API_URY_DS2_en_csv_v2_5255430.csv"
paraguai = "https://raw.githubusercontent.com/anamacao/analise_dados/main/dados/MERCOSUL_Paraguai_API_PRY_DS2_en_csv_v2_5213758.csv"

# %%
df_brasil = pd.read_csv(brasil)
df_brasil
# Out:
#    Country Name Country Code  \
# 0        Brasil          BRA
# 1        Brasil          BRA
# 2        Brasil          BRA
# 3        Brasil          BRA
# 4        Brasil          BRA
# ..          ...          ...
# 58       Brasil          BRA
# 59       Brasil          BRA
# 60       Brasil          BRA
# 61       Brasil          BRA
# 62       Brasil          BRA
#
#                                        Indicator Name     Indicator Code  \
# 0   Exportações de alta tecnologia (% de exportaçõ...  TX.VAL.TECH.MF.ZS
# 1    Índice de termos de permuta líquida (2000 = 100)  TT.PRI.MRCH.XD.WD
# 2                  Comércio de mercadorias (% do PIB)  TG.VAL.TOTL.GD.ZS
# 3                                    População, total        SP.POP.TOTL
# 4                  Crescimento da população (anual %)        SP.POP.GROW
# ..                                                ...                ...
# 58           Remessas pessoais, recebidas (US$ atual)  BX.TRF.PWKR.CD.DT
# ...
